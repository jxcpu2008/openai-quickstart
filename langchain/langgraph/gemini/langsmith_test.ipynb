# %%
import os

# 开启 LangSmith 跟踪，便于调试和查看详细执行信息
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = "GeminiChatBot"

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="详细介绍下 LangGraph 项目",
)

print(response.text)
# Out:
# LangGraph 是 LangChain 生态系统中的一个强大且专门的库，它旨在帮助开发者构建更复杂、更健壮、具有高级控制流和状态管理能力的 LLM 应用程序。你可以将其理解为 **为多步骤、多代理 LLM 应用程序设计的状态机或编排引擎**。
#
# 传统的 LangChain 链（Chains）通常是顺序执行的，虽然可以处理一些条件逻辑，但在面对需要循环、动态决策、多个代理协作以及持久化状态的复杂场景时，就显得力不从心。LangGraph 正是为了解决这些问题而诞生的。
#
# ### 核心理念与解决的问题
#
# LangGraph 的核心理念是基于 **图 (Graph)** 的结构来定义应用程序的执行流程。在 LangGraph 中：
#
# 1.  **节点 (Nodes)**：代表应用程序中的一个处理单元，可以是调用一个 LLM、使用一个工具、执行一个自定义函数、或者另一个 LangChain Runnable。
# 2.  **边 (Edges)**：定义了节点之间的转换关系。可以是从一个节点到另一个节点的固定转换，也可以是基于某些条件进行动态路由的条件转换。
# 3.  **状态 (State)**：一个可变的、在整个图执行过程中共享和更新的对象。节点的操作都会基于当前状态，并返回对状态的更新。这是实现复杂逻辑和循环的关键。
#
# **LangGraph 解决的主要问题包括：**
#
# *   **复杂控制流：** 允许定义非线性的、分支的、循环的执行路径，这是构建智能代理（Agents）的基础。
# *   **状态管理：** 提供清晰的方式来定义和传递整个应用程序的状态，确保信息在不同步骤和代理之间正确同步。
# *   **多代理协作：** 便于构建由多个不同功能的 LLM 代理协同工作的系统，每个代理负责特定任务，并根据图的定义进行交互。
# *   **持久性与容错：** 由于有明确的状态和流程定义，更容易实现持久化和从中断中恢复。
# *   **工具调用与规划：** 原生支持 LLM 的工具调用能力，并能基于工具调用的结果进行后续的决策和规划。
# *   **人机协作 (Human-in-the-Loop)：** 可以在流程中加入人工审核或干预的步骤。
#
# ### LangGraph 的核心组件与工作原理
#
# 1.  **`StateGraph`：**
#     *   这是构建 LangGraph 应用程序的核心类。你使用它来定义图的结构。
#     *   需要定义一个 `GraphState` 类（通常是一个 `TypedDict`），它将作为整个图在执行过程中共享和更新的状态。
#
#     ```python
#     from typing import TypedDict, List
#
#     class GraphState(TypedDict):
#         messages: List[str] # 示例：存储对话消息
#         tool_output: str # 示例：存储工具执行结果
#         # ... 其他你需要的状态变量
#     ```
#
# 2.  **节点 (Nodes)：**
#     *   通过 `add_node(name, runnable)` 方法添加。
#     *   每个节点都是一个可执行的单元，它接收当前的 `GraphState` 作为输入，执行一些逻辑（如调用 LLM、执行工具、处理数据），然后返回一个字典，其中的键值对用于更新 `GraphState`。
#
#     ```python
#     def call_llm(state: GraphState) -> GraphState:
#         # 假设这里调用 LLM，并返回新的消息
#         print("---CALL LLM---")
#         return {"messages": state["messages"] + ["New message from LLM"]}
#
#     def use_tool(state: GraphState) -> GraphState:
#         # 假设这里执行工具，并返回工具输出
#         print("---USE TOOL---")
#         return {"tool_output": "Result from tool"}
#
#     # graph = StateGraph(GraphState)
#     # graph.add_node("llm", call_llm)
#     # graph.add_node("tool", use_tool)
#     ```
#
# 3.  **边 (Edges)：**
#     *   **固定边 (Fixed Edges)：** 通过 `add_edge(source, target)` 定义，表示从一个节点执行完后直接跳转到另一个节点。
#     *   **条件边 (Conditional Edges)：** 通过 `add_conditional_edges(source, condition_router, mapping)` 定义。
#         *   `condition_router` 是一个函数，它接收当前的 `GraphState` 作为输入，并返回一个字符串（或预定义的特殊值如 `END`）。
#         *   `mapping` 是一个字典，将 `condition_router` 的返回值映射到目标节点或 `END`。这使得流程可以根据条件动态地路由到不同的路径。
#
#     ```python
#     # 示例条件路由器
#     def should_continue(state: GraphState) -> str:
#         if "tool_output" in state and state["tool_output"]:
#             return "tool_used"
#         return "no_tool"
#
#     # graph.add_conditional_edges(
#     #     "llm",
#     #     should_continue,
#     #     {
#     #         "tool_used": "tool", # 如果LLM决定用工具，则跳转到tool节点
#     #         "no_tool": END      # 如果LLM没用工具，则结束
#     #     }
#     # )
#     ```
#
# 4.  **入口点 (Entry Point) 和 出口点 (Exit Point)：**
#     *   `set_entry_point(node_name)`：定义图的起始节点。
#     *   `set_finish_point(node_name)`：定义图的结束节点（或使用 `END` 作为条件边的目标）。
#
# 5.  **编译与执行：**
#     *   定义完所有节点和边后，需要调用 `graph.compile()` 来编译图，得到一个 LangChain Runnable。
#     *   这个编译后的 Runnable 就可以像其他 LangChain Runnable 一样，通过 `.invoke()` 或 `.stream()` 方法进行调用，并传入初始状态。
#
#     ```python
#     # full_graph = graph.compile()
#     # for s in full_graph.stream({"messages": ["Hello"] }):
#     #     print(s)
#     ```
#
# ### LangGraph 的主要特点和优势
#
# 1.  **基于图的声明式编程：** 使得复杂的工作流一目了然，易于设计和维护。
# 2.  **强大的状态管理：** `GraphState` 机制确保了信息在整个流程中的一致性和可传递性，是实现复杂逻辑的关键。
# 3.  **原生支持循环 (Loops)：** 这是 LangGraph 最强大的特性之一。通过条件边和智能的路由器，可以轻松实现代理的自我反思、多次尝试、修正错误等循环行为，从而实现真正的“代理ic”能力。例如，一个代理可以：思考 -> 尝试 -> 检查结果 -> 如果不满意则再次思考 -> 再次尝试，直到达到满意结果或达到最大尝试次数。
# 4.  **多代理系统：** 可以将每个代理封装为一个子图或节点，然后通过主图来协调它们之间的交互和信息传递。
# 5.  **与 LangChain 无缝集成：** LangGraph 本身是 LangChain 生态的一部分，因此你可以直接在 LangGraph 节点中使用任何 LangChain 的 `Runnable`，包括 LLM、Tool、Retrievers、PromptTemplates 等。
# 6.  **可观测性 (Observability)：** 结合 LangSmith (LangChain 的可观测性平台)，可以清晰地追踪 LangGraph 的执行路径、每个节点的状态变化、以及 LLM 的调用详情，极大地简化了调试和优化过程。
# 7.  **灵活的工具使用：** LLM 可以决定何时使用哪个工具，并将工具的输出反馈到状态中，供后续决策使用。
# 8.  **高度可定制：** 几乎所有方面都可以通过自定义函数或 LangChain Runnable 进行替换和扩展。
#
# ### 典型应用场景
#
# *   **自主代理 (Autonomous Agents)：** 构建能够自主规划、执行任务、自我纠正的复杂代理，例如代码生成、数据分析、文档处理等。
# *   **多轮对话系统：** 管理复杂对话的上下文、用户意图识别、回复生成和多轮交互。
# *   **高级RAG（检索增强生成）：** 结合多步骤检索、重排、验证、以及基于检索结果的动态生成。
# *   **复杂工作流自动化：** 将多个LLM调用、API调用、人工审核步骤等串联起来，形成自动化的业务流程。
# *   **智能客服与帮助台：** 处理用户请求，根据复杂逻辑路由到不同的知识库、专家代理或人工客服。
#
# ### LangGraph 与 LangChain 的关系
#
# *   **LangChain (LCL)** 是一个更广泛的框架，提供构建 LLM 应用的各种“积木”和基础链。它更关注于单个步骤的连接和数据流。
# *   **LangGraph (LCG)** 是 LangChain 框架内部的一个**高级模块**，它建立在 LangChain 的积木之上，专注于解决 **控制流、状态管理和复杂编排** 问题。你可以理解为：LangGraph 用 LangChain 的积木来搭建立体化的、带反馈回路的、有生命力的“建筑群”。
#
# 简而言之，当你需要超越简单的顺序链，构建具有决策能力、循环能力和多代理协作的“大脑”时，LangGraph 就是你的首选工具。
